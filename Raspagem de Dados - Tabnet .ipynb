# %%
#!/usr/bin/env python
# coding: utf-8

# ### Processo de Extração de dados do TabNet Prefeitura de São Paulo 

# Importar bibliotecas do modelo 

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import pyautogui
import time
import pyperclip

# para rodar o chrome em 2º plano
# from selenium.webdriver.chrome.options import Options
# chrome_options = Options()
# chrome_options.headless = True # also works
# nav = webdriver.Chrome(options=chrome_options)


# ##### **Consulta 1**: Definir um caminho de extração dos dados diários de mortalidade por covid


# Abrir o navegador
nav = webdriver.Chrome()

#   Acessar o link: http://tabnet.saude.prefeitura.sp.gov.br/cgi/deftohtm3.exe?secretarias/saude/TABNET/SIM_PROV/obitop.def
nav.get("http://tabnet.saude.prefeitura.sp.gov.br/cgi/deftohtm3.exe?secretarias/saude/TABNET/SIM_PROV/obitop.def")

#   Escolher em "Linha" a opção "Dia do óbito"
diaobito = nav.find_element_by_xpath('/html/body/center/div/form/div[2]/div/div[1]/select/option[18]')
diaobito.click()

#   Escolher em "Coluna" a opção "Distrito Admin residência "
distrito = nav.find_element_by_xpath('/html/body/center/div/form/div[2]/div/div[2]/select/option[8]')
distrito.click()

#   Escolher em "Perídos Disponíveis" a opção "2020" e "2021"
ano2020 = nav.find_element_by_xpath('/html/body/center/div/form/div[3]/div/select/option[2]')
ano2020.click()

#   Escolher em "Seleções Disponíveis" o filtro "Óbitos por Covid 19"
obitosporcovid = nav.find_element_by_xpath('/html/body/center/div/form/div[4]/div[1]/div/div[1]/img')
obitosporcovid.click()

# Escolher a opção "Óbitos confirmados de COVID 19"
covidconfirmado = nav.find_element_by_xpath('/html/body/center/div/form/div[4]/div[1]/div/div[1]/select/option[3]')
covidconfirmado.click()

# Deselecionar a opção "Todas as categorias"
covidconfirmado2 = nav.find_element_by_xpath('/html/body/center/div/form/div[4]/div[1]/div/div[1]/select/option[1]')
covidconfirmado2.click()

#   Apertar o botão "Mostrar"
mostrar = nav.find_element_by_xpath('/html/body/center/div/form/div[4]/div[2]/div[2]/input[1]').send_keys(Keys.ENTER)

#Selecionar o resultado
pyautogui.hotkey("ctrl", 'a')

time.sleep(2)

# Copiar a tabela
pyautogui.hotkey("ctrl", 'c')

time.sleep(2)

# Acessar a planilha: http://tabnet.saude.prefeitura.sp.gov.br/cgi/deftohtm3.exe?secretarias/saude/TABNET/RSRAG/sragh.def
nav.get("https://docs.google.com/spreadsheets/d/1O7osBa8_UXR7hNfWXlrwUYCGKX92KZVPyw9MZ1OVRgc/edit?usp=sharing")

time.sleep(5)

# Colar a tabela na planilha
pyautogui.hotkey("ctrl", 'v')

time.sleep(5)


# ##### **Consulta 1.2**: Fazer o mesmo caminho para os obitos suspeitos por covid



# Abrir o navegador
nav = webdriver.Chrome()

#   Acessar o link: http://tabnet.saude.prefeitura.sp.gov.br/cgi/deftohtm3.exe?secretarias/saude/TABNET/SIM_PROV/obitop.def
nav.get("http://tabnet.saude.prefeitura.sp.gov.br/cgi/deftohtm3.exe?secretarias/saude/TABNET/SIM_PROV/obitop.def")

#   Escolher em "Linha" a opção "Dia do óbito"
diaobitosusp = nav.find_element_by_xpath('/html/body/center/div/form/div[2]/div/div[1]/select/option[18]')
diaobitosusp.click()

#   Escolher em "Coluna" a opção "Distrito Admin residência "
distrito = nav.find_element_by_xpath('/html/body/center/div/form/div[2]/div/div[2]/select/option[8]')
distrito.click()

#   Escolher em "Perídos Disponíveis" a opção "2020" e "2021"
ano2020 = nav.find_element_by_xpath('/html/body/center/div/form/div[3]/div/select/option[2]')
ano2020.click()

#   Escolher em "Seleções Disponíveis" o filtro "Óbitos por Covid 19"
obitosporcovid = nav.find_element_by_xpath('/html/body/center/div/form/div[4]/div[1]/div/div[1]/img')
obitosporcovid.click()

# Escolher a opção "Óbitos suspeitos de COVID 19"
covidconfirmado = nav.find_element_by_xpath('/html/body/center/div/form/div[4]/div[1]/div/div[1]/select/option[2]')
covidconfirmado.click()

# Deselecionar a opção "Todas as categorias"
covidconfirmado2 = nav.find_element_by_xpath('/html/body/center/div/form/div[4]/div[1]/div/div[1]/select/option[1]')
covidconfirmado2.click()

#   Apertar o botão "Mostrar"
mostrar = nav.find_element_by_xpath('/html/body/center/div/form/div[4]/div[2]/div[2]/input[1]').send_keys(Keys.ENTER)

#Selecionar o resultado
pyautogui.hotkey("ctrl", 'a')

time.sleep(2)

# Copiar a tabela
pyautogui.hotkey("ctrl", 'c')

time.sleep(2)

# Acessar a planilha: http://tabnet.saude.prefeitura.sp.gov.br/cgi/deftohtm3.exe?secretarias/saude/TABNET/RSRAG/sragh.def
nav.get("https://docs.google.com/spreadsheets/d/1jyabgIEKFNyZfrbuysv2I7FkUqfDQxAIULHRRysiwSI/edit?usp=sharing")

time.sleep(5)

# Colar a tabela na planilha
pyautogui.hotkey("ctrl", 'v')

time.sleep(5)


# ##### **Consulta 2**: Definir caminho de extração dos dados sobra a faixa etária das mortes por Covid-1


# Abrir o navegador
nav = webdriver.Chrome()

#   Acessar o link: http://tabnet.saude.prefeitura.sp.gov.br/cgi/deftohtm3.exe?secretarias/saude/TABNET/SIM_PROV/obitop.def
nav.get("http://tabnet.saude.prefeitura.sp.gov.br/cgi/deftohtm3.exe?secretarias/saude/TABNET/SIM_PROV/obitop.def")

#   Escolher em "Linha" a opção "Distrito Admin residência "
distritoFE = nav.find_element_by_xpath('/html/body/center/div/form/div[2]/div/div[1]/select/option[11]')
distritoFE.click()

#   Escolher em "Coluna" a opção "Faixa Etária (12)"
faixaetaria = nav.find_element_by_xpath('/html/body/center/div/form/div[2]/div/div[2]/select/option[17]')
faixaetaria.click()

#   Escolher em "Perídos Disponíveis" a opção "2020" e "2021"
ano2020obito = nav.find_element_by_xpath('/html/body/center/div/form/div[3]/div/select/option[2]')
ano2020obito.click()

#   Escolher em "Seleções Disponíveis" o filtro "Classificação final"
obitosporcovid = nav.find_element_by_xpath('/html/body/center/div/form/div[4]/div[1]/div/div[1]/img')
obitosporcovid.click()

# Escolher a opção "Óbitos confirmados de COVID 19"
covidconfirmado = nav.find_element_by_xpath('/html/body/center/div/form/div[4]/div[1]/div/div[1]/select/option[3]')
covidconfirmado.click()

# Deselecionar a opção "Todas as categorias"
covidconfirmado2 = nav.find_element_by_xpath('/html/body/center/div/form/div[4]/div[1]/div/div[1]/select/option[1]')
covidconfirmado2.click()


#   Apertar o botão "Mostrar"
nav.find_element_by_xpath('/html/body/center/div/form/div[4]/div[2]/div[2]/input[1]').send_keys(Keys.ENTER)


time.sleep(2)

# Copiar a tabela
pyautogui.hotkey("ctrl", 'c')

time.sleep(2)

# Acessar a planilha: http://tabnet.saude.prefeitura.sp.gov.br/cgi/deftohtm3.exe?secretarias/saude/TABNET/RSRAG/sragh.def
nav.get("https://docs.google.com/spreadsheets/d/1OZRpmCka_05FgWoMt9iCZ1c0HmahXVdUcBtAgEFxv68/edit?usp=sharing")

time.sleep(5)

# Colar a tabela na planilha
pyautogui.hotkey("ctrl", 'v')

time.sleep(5)


# ##### **Consulta 3**: Definir caminho de extração dos dados diários de SRAG por covid

# Abrir o navegador
nav = webdriver.Chrome()

#   Acessar o link: http://tabnet.saude.prefeitura.sp.gov.br/cgi/deftohtm3.exe?secretarias/saude/TABNET/RSRAG/sragh.def
nav.get("http://tabnet.saude.prefeitura.sp.gov.br/cgi/deftohtm3.exe?secretarias/saude/TABNET/RSRAG/sragh.def")

#   Escolher em "Linha" a opção "Ano Mês Dia Notificação"
diaSRAG = nav.find_element_by_xpath('/html/body/center/div/form/div[2]/div/div[1]/select/option[2]')
diaSRAG.click()

#   Escolher em "Coluna" a opção "Distrito Admin residência"
distritoSRAG = nav.find_element_by_xpath('/html/body/center/div/form/div[2]/div/div[2]/select/option[13]')
distritoSRAG.click()

#   Escolher em "Perídos Disponíveis" a opção "2020" e "2021"
ano2020SRAG = nav.find_element_by_xpath('/html/body/center/div/form/div[3]/div/select/option[2]')
ano2020SRAG.click()

#   Escolher em "Seleções Disponíveis" o filtro "Classificação final"
selefin = nav.find_element_by_xpath('/html/body/center/div/form/div[4]/div[1]/div/div[1]/img')
selefin.click()

# Escolher a opção "SRAG por Covid 19"
sragcovid = nav.find_element_by_xpath('/html/body/center/div/form/div[4]/div[1]/div/div[1]/select/option[4]')
sragcovid.click()

# Deselecionar a opção "Todas as categorias"
sragcovid2 = nav.find_element_by_xpath('/html/body/center/div/form/div[4]/div[1]/div/div[1]/select/option[1]')
sragcovid2.click()


#   Apertar o botão "Mostrar"
nav.find_element_by_xpath('/html/body/center/div/form/div[4]/div[2]/div[2]/input[1]').send_keys(Keys.ENTER)


time.sleep(2)

# Copiar a tabela
pyautogui.hotkey("ctrl", 'c')

time.sleep(2)

# Acessar a planilha: http://tabnet.saude.prefeitura.sp.gov.br/cgi/deftohtm3.exe?secretarias/saude/TABNET/RSRAG/sragh.def
nav.get("https://docs.google.com/spreadsheets/d/17nY-6gfxP4-JNIgpMwOd7JrvjzTBdjcEFkOK01FWisE/edit?usp=sharing")

time.sleep(5)

# Colar a tabela na planilha
pyautogui.hotkey("ctrl", 'v')

time.sleep(5)


# ##### **Consulta 4**: Definir caminho de extração dos dados de internações em de SRAG por covid

# Abrir o navegador
nav = webdriver.Chrome()

#   Acessar o link: http://tabnet.saude.prefeitura.sp.gov.br/cgi/deftohtm3.exe?secretarias/saude/TABNET/RSRAG/sragh.def
nav.get("http://tabnet.saude.prefeitura.sp.gov.br/cgi/deftohtm3.exe?secretarias/saude/TABNET/RSRAG/sragh.def")

#   Escolher em "Linha" a opção "Ano Mês Dia Notificação"
diaSRAGint = nav.find_element_by_xpath('/html/body/center/div/form/div[2]/div/div[1]/select/option[2]')
diaSRAGint.click()

#   Escolher em "Coluna" a opção "Distrito Admin residência"
distritoSRAGint = nav.find_element_by_xpath('/html/body/center/div/form/div[2]/div/div[2]/select/option[13]')
distritoSRAGint.click()

#   Escolher em "Perídos Disponíveis" a opção "2020" e "2021"
ano2020SRAGint = nav.find_element_by_xpath('/html/body/center/div/form/div[3]/div/select/option[2]')
ano2020SRAGint.click()

#   Escolher em "Seleções Disponíveis" o filtro "Classificação final"
selefin = nav.find_element_by_xpath('/html/body/center/div/form/div[4]/div[1]/div/div[1]/img')
selefin.click()

# Escolher a opção "SRAG por Covid 19"
sragcovid = nav.find_element_by_xpath('/html/body/center/div/form/div[4]/div[1]/div/div[1]/select/option[4]')
sragcovid.click()

# Deselecionar a opção "Todas as categorias"
sragcovid2 = nav.find_element_by_xpath('/html/body/center/div/form/div[4]/div[1]/div/div[1]/select/option[1]')
sragcovid2.click()

#   Escolher em "Seleções Disponíveis" a opção "Internado em UTI" e "SRAG por Covid"
intUTISRAG = nav.find_element_by_xpath('/html/body/center/div/form/div[4]/div[1]/div/div[44]/img')
intUTISRAG.click()
intUTISRAGsim = nav.find_element_by_xpath('/html/body/center/div/form/div[4]/div[1]/div/div[44]/select/option[2]')
intUTISRAGsim.click()

#   Apertar o botão "Mostrar"
nav.find_element_by_xpath('/html/body/center/div/form/div[4]/div[2]/div[2]/input[1]').send_keys(Keys.ENTER)

time.sleep(2)

# Copiar a tabela
pyautogui.hotkey("ctrl", 'c')

time.sleep(2)

# Acessar a planilha
nav.get("https://docs.google.com/spreadsheets/d/1LKxnS8T-rly4t58mE9vJp2YGHyFzAQW-EpnwYPcCdLg/edit?usp=sharing")

time.sleep(5)

# Colar a tabela na planilha
pyautogui.hotkey("ctrl", 'v')

time.sleep(5)
